# %%
s="Arman"
print(s[3])
print(s[-2])
q="tiyiooijih"
print(q[6])
print(q[-14])
# Out:
# a
# a
# i
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-c83a3cf5aeec> in <module>
#       4 q="tiyiooijih"
#       5 print(q[6])
# ----> 6 print(q[-14])
#
# IndexError: string index out of range

# %% [markdown]
# Using slicing operator

# %%
s="learning python is very easy"
print(s[1:7:1])
print(s[:7:-1])
print(s[1:7:2])
print(s[::])
print(s[1:])
# Out:
# earnin
# ysae yrev si nohtyp
# eri
# learning python is very easy
# earning python is very easy

# %%
s="malylam"
l=print(s[::-1])
if(s==l):
    print("Palindrome")
else:
    print("Not palindrome")
# Out:
# malylam
# Not palindrome

# %%
s1=input("Enter string 1:")
s2=input("Enter string 2:")
if(s1==s2):
    print("Both are equal")
elif(s1<s2):
    print("s2 is greater")
# Out:
# Enter string 1:wer
# Enter string 2:wwr
# s2 is greater

# %% [markdown]
# Joining of string

# %%
s=("ABC","QWE","IOP")
s1="-".join(s)
print(s1)
# Out:
# ABC-QWE-IOP

# %%
n="Meet"
s=80000
a=25
s1=("{}`s salary is {} and age is {}".format(n,s,a))
print(s1)
s2=("{0}`s salary is {2} and age is {1}".format(n,s,a))
print(s2)
# Out:
# Meet`s salary is 80000 and age is 25
# Meet`s salary is 25 and age is 80000

# %% [markdown]
# Removing spaces

# %%
t="apple pol  "
print(len(t))
s=t.rstrip()
print(len(s))
print(s)

t1="apple pol"
print(len(t1))
s1=t1.rstrip("ol")
print(len(s1))
print(s1)
# Out:
# 11
# 9
# apple pol
# 9
# 7
# apple p

# %%
s="hello There"
t=s.upper()
print(t)
# Out:
# HELLO THERE

# %%
s="hello There"
t=s.lower()
print(t)
# Out:
# hello there

# %%
s="hello There"
t=s.swapcase()
print(t)
# Out:
# HELLO tHERE

# %%
s="hello ThEre"
t=s.title()
print(t)
# Out:
# Hello There

# %%
s="hello ThEre"
t=s.capitalize()
print(t)
# Out:
# Hello there

# %%
s="Company123"
t=s.isalnum()
print(t)
# Out:
# False

# %%
s="Company"
t=s.isalpha()
print(t)
# Out:
# True

# %%
s="123"
t=s.isdigit()
print(t)
# Out:
# True

# %%
s="company123"
t=s.islower()
print(t)
# Out:
# True

# %%
s="COMPANY123"
t=s.isupper()
print(t)
# Out:
# True

# %%
s="Company123"
s1="Com 2"
t=s.istitle()
t1=s1.istitle()
print(t)
print(t1)
# Out:
# True
# True

# %%
a="Myname2"
b="2Myname"
print(a.isidentifier())
print(b.isidentifier())
# Out:
# True
# False

# %%
s1="Hello how are you"
count=0
for i in s1:
    if i.isspace():
        count=count+1
print("space:",count)
# Out:
# space: 3

# %% [markdown]
# WAP to create a string made of 1st,middle and last character

# %%
s="James"
print(s[0:1:])
print(s[4:0:-4])
print(s[2:0:-2])
# Out:
# J
# s
# m
